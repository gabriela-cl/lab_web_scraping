# %% [markdown]
# ### Lab for today:
# Choose your favorite 3 book categories from this website: https://books.toscrape.com/
# and create a dataframe for each of the 3 categories, storing:
# - the title of the book
# - the price of the book
# - the number of stars it has

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = "https://books.toscrape.com/"
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.content)

# %%
#Category Art
art = "https://books.toscrape.com/catalogue/category/books/art_25/index.html"
response_a = requests.get(art)
response_a
# Out:
# <Response [200]>

# %%
soup_a = BeautifulSoup(response_a.content)

# %%
print(soup_a.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="no-js" lang="en-us">
#  <!--<![endif]-->
#  <head>
#   <title>
#    Art |
#      Books to Scrape - Sandbox
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <meta content="24th Jun 2016 09:29" name="created"/>
#   <meta content="
#
# " name="description"/>
#   <meta content="width=device-width" name="viewport"/>
#   <meta content="NOARCHIVE,NOCACHE" name="robots"/>
#   <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->
#   <!--[if lt IE 9]>
#         <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>
#         <![endif]-->
#   <link href="../../../../static/oscar/favicon.ico" rel="shortcut icon"/>
# ...

# %%
#titles

titles_list_art = []
for title in soup_a.find_all("a", title = True):
    title = title.get_text()
    titles_list_art.append(title)

titles_list_art
#see the whole title
# Out:
# ['Wall and Piece',
#  'Feathers: Displays of Brilliant ...',
#  'Art and Fear: Observations ...',
#  'The New Drawing on ...',
#  'History of Beauty',
#  'The Story of Art',
#  'The Art Book',
#  'Ways of Seeing']

# %%
#price
price_list_art = []
for price in soup_a.find_all("p", class_ = "price_color"):
    price = price.get_text()
    price_list_art.append(price)

price_list_art
# Out:
# ['£44.18',
#  '£49.05',
#  '£48.63',
#  '£43.02',
#  '£10.29',
#  '£41.14',
#  '£32.34',
#  '£39.51']

# %%
star_ratings = soup_a.find_all('p', class_='star-rating')
star_ratings
# Out:
# [<p class="star-rating Four">
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  </p>,
#  <p class="star-rating Three">
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  </p>,
#  <p class="star-rating Four">
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  </p>,
#  <p class="star-rating Three">
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  </p>,
#  <p class="star-rating Four">
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  </p>,
#  <p class="star-rating Four">
#  <i class="icon-star"></i>
# ...

# %%
star_ratings = soup_a.find_all('p', class_='star-rating')
star_rating_list = []

# Extract and print the "star-rating x" for each element
for rating in star_ratings:
    class_list = rating['class'] 
# rating['class']: This expression is accessing the class attribute of the rating Beautiful Soup object.
#Type: The result is a list of strings, where each string is a class name applied to the element.
    
    # Filter out "star-rating" and get the actual rating
    star_rating = [s for s in class_list if s != 'star-rating']
    star_rating_list.append(star_rating[0])

star_rating_list
# Out:
# ['Four', 'Three', 'Four', 'Three', 'Four', 'Four', 'Two', 'Five']

# %%
#create a dataframe

books_dict = {"title":book_titles, "author":all_authors}
books_df = pd.DataFrame(books_dict)
books_df.head()

# %%
#Category Science

# %%
#Category Travel
